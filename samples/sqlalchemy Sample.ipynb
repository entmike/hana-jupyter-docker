# %%
import sqlalchemy
# %reload_ext sql

# %config SqlMagic.displaylimit = 25

hxe_connection = 'hana://SYSTEM:HXEHana1@hxe:39017';

# %sql $hxe_connection
# Out:
# 'Connected: SYSTEM@None'

# %%
# %sql select * FROM M_TABLES;
# Out:
#  * hana://SYSTEM:***@hxe:39017
# Done.
# [('SYS', 'RS_TABLES_', 888, 427472, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'RS_COLUMNS_', 17786, 6087624, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_INDEXES_', 648, 154176, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'RS_VIEWS_', 830, 1296560, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_PROCEDURES_', 823, 1993896, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_PROCPARAMS_', 3684, 907872, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_SEQUENCES_', 9, 16952, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_SYNONYMS_', 830, 188008, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_SCHEMAS_', 27, 16768, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_PRINCIPALS_', 41, 17296, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
#  ('SYS', 'P_LAST_PASSWORDS_', 0, 0, 'FALSE', 'ROW', 'FALSE', 'FALSE', 'FALSE'),
# ...
